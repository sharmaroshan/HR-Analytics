# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Importing Libraries and Dataset**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the data

train = pd.read_csv('drive/My Drive/Projects/HR Analytics/train.csv')
test = pd.read_csv('drive/My Drive/Projects/HR Analytics/test.csv')

# getting their shapes
print("Shape of train :", train.shape)
print("Shape of test :", test.shape)
# Out:
# Shape of train : (54808, 14)
# Shape of test : (23490, 13)

# %% [markdown]
# **Data Analysis**

# %%
train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
test.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# 1                  5              0            0                  51
# 2                  4              0            0                  47
# 3                  9              0            0                  65
# 4                  7              0            0                  61

# %%
# describing the training set

train.describe(include = 'all')
# Out:
#          employee_id         department    region   education gender  \
# count   54808.000000              54808     54808       52399  54808
# unique           NaN                  9        34           3      2
# top              NaN  Sales & Marketing  region_2  Bachelor's      m
# freq             NaN              16840     12343       36669  38496
# mean    39195.830627                NaN       NaN         NaN    NaN
# std     22586.581449                NaN       NaN         NaN    NaN
# min         1.000000                NaN       NaN         NaN    NaN
# 25%     19669.750000                NaN       NaN         NaN    NaN
# 50%     39225.500000                NaN       NaN         NaN    NaN
# 75%     58730.500000                NaN       NaN         NaN    NaN
# max     78298.000000                NaN       NaN         NaN    NaN
#
#        recruitment_channel  no_of_trainings           age  \
# count                54808     54808.000000  54808.000000
# unique                   3              NaN           NaN
# top                  other              NaN           NaN
# freq                 30446              NaN           NaN
# mean                   NaN         1.253011     34.803915
# std                    NaN         0.609264      7.660169
# min                    NaN         1.000000     20.000000
# 25%                    NaN         1.000000     29.000000
# 50%                    NaN         1.000000     33.000000
# 75%                    NaN         1.000000     39.000000
# max                    NaN        10.000000     60.000000
#
#         previous_year_rating  length_of_service  KPIs_met >80%   awards_won?  \
# count           50684.000000       54808.000000   54808.000000  54808.000000
# unique                   NaN                NaN            NaN           NaN
# top                      NaN                NaN            NaN           NaN
# freq                     NaN                NaN            NaN           NaN
# mean                3.329256           5.865512       0.351974      0.023172
# std                 1.259993           4.265094       0.477590      0.150450
# min                 1.000000           1.000000       0.000000      0.000000
# 25%                 3.000000           3.000000       0.000000      0.000000
# 50%                 3.000000           5.000000       0.000000      0.000000
# 75%                 4.000000           7.000000       1.000000      0.000000
# max                 5.000000          37.000000       1.000000      1.000000
#
#         avg_training_score   is_promoted
# count         54808.000000  54808.000000
# unique                 NaN           NaN
# top                    NaN           NaN
# freq                   NaN           NaN
# mean             63.386750      0.085170
# std              13.371559      0.279137
# min              39.000000      0.000000
# 25%              51.000000      0.000000
# 50%              60.000000      0.000000
# 75%              76.000000      0.000000
# max              99.000000      1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
# employee_id             54808 non-null int64
# department              54808 non-null object
# region                  54808 non-null object
# education               52399 non-null object
# gender                  54808 non-null object
# recruitment_channel     54808 non-null object
# no_of_trainings         54808 non-null int64
# age                     54808 non-null int64
# previous_year_rating    50684 non-null float64
# length_of_service       54808 non-null int64
# KPIs_met >80%           54808 non-null int64
# awards_won?             54808 non-null int64
# avg_training_score      54808 non-null int64
# is_promoted             54808 non-null int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.9+ MB

# %%
# checking if there is any NULL value in the dataset

train.isnull().any()
# Out:
# employee_id             False
# department              False
# region                  False
# education                True
# gender                  False
# recruitment_channel     False
# no_of_trainings         False
# age                     False
# previous_year_rating     True
# length_of_service       False
# KPIs_met >80%           False
# awards_won?             False
# avg_training_score      False
# is_promoted             False
# dtype: bool

# %%
test.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %% [markdown]
# **UNi-variate Data Visualization**

# %%
# looking at the most popular departments

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopword).generate(str(train['department']))

plt.rcParams['figure.figsize'] = (12, 8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular Departments', fontsize = 30)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f036f9e3128>

# %%
# checkig the no. of Employees Promoted

train['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
# finding the %age of people promoted

promoted = (4668/54808)*100
print("Percentage of Promoted Employees is {:.2f}%".format(promoted))
# Out:
# Percentage of Promoted Employees is 8.52%

# %%
#plotting a scatter plot 

plt.hist(train['is_promoted'])
plt.title('plot to show the gap in Promoted and Non-Promoted Employees', fontsize = 30)
plt.xlabel('0 -No Promotion and 1- Promotion', fontsize = 20)
plt.ylabel('count')
plt.show()

# %%
# checking the distribution of the avg_training score of the Employees

plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(train['avg_training_score'], color = 'blue')
plt.title('Distribution of Training Score among the Employees', fontsize = 30)
plt.xlabel('Average Training Score', fontsize = 20)
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
train['awards_won?'].value_counts()
# Out:
# 0    53538
# 1     1270
# Name: awards_won?, dtype: int64

# %%
# plotting a donut chart for visualizing each of the recruitment channel's share

size = [53538, 1270]
colors = ['magenta', 'brown']
labels = "Awards Won", "NO Awards Won"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing a Percentage of employees who won awards', fontsize = 30)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
train['KPIs_met >80%'].value_counts()
# Out:
# 0    35517
# 1    19291
# Name: KPIs_met >80%, dtype: int64

# %%
# plotting a pie chart


size = [35517, 19291]
labels = "Not Met KPI > 80%", "Met KPI > 80%"
colors = ['violet', 'grey']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Gap in Employees in terms of KPI', fontsize = 30)
plt.axis('off')
plt.legend()
plt.show()

# %%
# checking the distribution of length of service

sns.distplot(train['length_of_service'], color = 'green')
plt.title('Distribution of length of service among the Employees', fontsize = 30)
plt.xlabel('Length of Service in years', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
train['previous_year_rating'].value_counts().sort_values().plot.bar(color = 'violet', figsize = (15, 7))
plt.title('Distribution of Previous year rating of the Employees', fontsize = 30)
plt.xlabel('Ratings', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
# checking the distribution of age of Employees in the company

sns.distplot(train['age'], color = 'red')
plt.title('Distribution of Age of Employees', fontsize = 30)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# checking the different no. of training done by the employees

plt.rcParams['figure.figsize'] = (17, 7)
sns.violinplot(train['no_of_trainings'], color = 'purple')
plt.title('No. of trainings done by the Employees', fontsize = 30)
plt.xlabel('No. of Trainings', fontsize = 15)
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
# checking the different types of recruitment channels for the company

train['recruitment_channel'].value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
# plotting a donut chart for visualizing each of the recruitment channel's share

size = [30446, 23220, 1142]
colors = ['yellow', 'red', 'lightgreen']
labels = "Others", "Sourcing", "Reffered"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing share of different Recruitment Channels', fontsize = 30)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
# checing the most popular education degree among the employees

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopword, max_words = 5).generate(str(train['education']))

plt.rcParams['figure.figsize'] = (12, 8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular Degrees among the Employees', fontsize = 30)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f03701f64e0>

# %%
# checking the gender gap

train['gender'].value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
# plotting a pie chart

size = [38496, 16312]
labels = "Male", "Female"
colors = ['yellow', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing GenderGap', fontsize = 30)
plt.axis('off')
plt.legend()
plt.show()

# %%
# checking the different regions of the company

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(train['region'], color = 'pink')
plt.title('Different Regions in the company', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('Region Code', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# **Bi-varaiate Data Visualization**

# %%
# scatter plot between average training score and is_promoted

data = pd.crosstab(train['avg_training_score'], train['is_promoted'])
data.div(data.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['darkred', 'lightgreen'])

plt.title('Looking at the Dependency of Training Score in promotion', fontsize = 30)
plt.xlabel('Average Training Scores', fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# **As, the Training Scores Increases, the chances of Promotion Increases Highly**

# %%
# checking dependency of different regions in promotion

data = pd.crosstab(train['region'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['lightblue', 'purple'])

plt.title('Dependency of Regions in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Different Regions of the Company', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **The above graph shows that there is no biasedness over regions in terms of Promotion as all the regions share promotions almost equally.**

# %%
# dependency of awards won on promotion

data = pd.crosstab(train['awards_won?'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 8), color = ['magenta', 'purple'])

plt.title('Dependency of Awards in determining Promotion', fontsize = 30)
plt.xlabel('Awards Won or Not', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **There is a very good chance of getting promoted if the employee has won an award**

# %%
#dependency of KPIs with Promotion

data = pd.crosstab(train['KPIs_met >80%'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 8), color = ['pink', 'darkred'])

plt.title('Dependency of KPIs in determining Promotion', fontsize = 30)
plt.xlabel('KPIs Met or Not', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **Again Having a good KPI score increases the chances of getting promoted in the company.**

# %%
# checking dependency on previous years' ratings

data = pd.crosstab(train['previous_year_rating'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (15, 8), color = ['violet', 'pink'])

plt.title('Dependency of Previous year Ratings in determining Promotion', fontsize = 30)
plt.xlabel('Different Ratings', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **The Above Graph clearly suggests that previous ratings matter a lot, if the ratings are high, the chances of being promoted  in the company increases and there is completely no promotion for the employees with previous year ratings = 0**

# %%
# checking how length of service determines the promotion of employees

data = pd.crosstab(train['length_of_service'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['pink', 'lightblue'])

plt.title('Dependency of Length of service in Promotions of Employees', fontsize = 30)
plt.xlabel('Length of service of employees', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking dependency of age factor in promotion of employees

data = pd.crosstab(train['age'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['lightblue', 'green'])

plt.title('Dependency of Age in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Age of Employees', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **This is Very Impressive that the company promotes employees of all the ages equally even the freshers have equal share of promotion and also the senior citizen employees are getting the equal share of Promotion in the Company**

# %%
# checking which department got most number of promotions

data = pd.crosstab(train['department'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['orange', 'lightgreen'])

plt.title('Dependency of Departments in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Different Departments of the Company', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **Again, Each of the departments have equal no. of promotions showing an equal developement in each of the departments of the company.**

# %%
# checking dependency of gender over promotion

data = pd.crosstab(train['gender'], train['is_promoted'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (7, 5), color = ['pink', 'yellow'])

plt.title('Dependency of Genders in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Gender', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# **The above plot shows that there is no partiality between males and females in terms of promotion**

# %% [markdown]
# **Data Pre-processing**

# %%
# filling missing values

train['education'].fillna(train['education'].mode()[0], inplace = True)
train['previous_year_rating'].fillna(1, inplace = True)

# again checking if there is any Null value left in the data
train.isnull().sum().sum()
# Out:
# 0

# %%
# filling missing values

test['education'].fillna(test['education'].mode()[0], inplace = True)
test['previous_year_rating'].fillna(1, inplace = True)

# again checking if there is any Null value left in the data
test.isnull().sum().sum()
# Out:
# 0

# %%
# removing the employee_id column

train = train.drop(['employee_id'], axis = 1)

train.columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
# saving the employee_id

emp_id = test['employee_id']

# removing the employee_id column

test = test.drop(['employee_id'], axis = 1)

test.columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score'],
#       dtype='object')

# %%
# defining the test set

x_test = test

x_test.columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score'],
#       dtype='object')

# %%
# one hot encoding for the test set

x_test = pd.get_dummies(x_test)

x_test.columns
# Out:
# Index(['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score',
#        'department_Analytics', 'department_Finance', 'department_HR',
#        'department_Legal', 'department_Operations', 'department_Procurement',
#        'department_R&D', 'department_Sales & Marketing',
#        'department_Technology', 'region_region_1', 'region_region_10',
#        'region_region_11', 'region_region_12', 'region_region_13',
#        'region_region_14', 'region_region_15', 'region_region_16',
#        'region_region_17', 'region_region_18', 'region_region_19',
#        'region_region_2', 'region_region_20', 'region_region_21',
#        'region_region_22', 'region_region_23', 'region_region_24',
#        'region_region_25', 'region_region_26', 'region_region_27',
#        'region_region_28', 'region_region_29', 'region_region_3',
#        'region_region_30', 'region_region_31', 'region_region_32',
#        'region_region_33', 'region_region_34', 'region_region_4',
#        'region_region_5', 'region_region_6', 'region_region_7',
#        'region_region_8', 'region_region_9', 'education_Bachelor's',
#        'education_Below Secondary', 'education_Master's & above', 'gender_f',
#        'gender_m', 'recruitment_channel_other', 'recruitment_channel_referred',
#        'recruitment_channel_sourcing'],
#       dtype='object')

# %%
# splitting the train set into dependent and independent sets

x = train.iloc[:, :-1]
y = train.iloc[:, -1]

print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (54808, 12)
# Shape of y: (54808,)

# %%
# one hot encoding for the train set

x = pd.get_dummies(x)

x.columns
# Out:
# Index(['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score',
#        'department_Analytics', 'department_Finance', 'department_HR',
#        'department_Legal', 'department_Operations', 'department_Procurement',
#        'department_R&D', 'department_Sales & Marketing',
#        'department_Technology', 'region_region_1', 'region_region_10',
#        'region_region_11', 'region_region_12', 'region_region_13',
#        'region_region_14', 'region_region_15', 'region_region_16',
#        'region_region_17', 'region_region_18', 'region_region_19',
#        'region_region_2', 'region_region_20', 'region_region_21',
#        'region_region_22', 'region_region_23', 'region_region_24',
#        'region_region_25', 'region_region_26', 'region_region_27',
#        'region_region_28', 'region_region_29', 'region_region_3',
#        'region_region_30', 'region_region_31', 'region_region_32',
#        'region_region_33', 'region_region_34', 'region_region_4',
#        'region_region_5', 'region_region_6', 'region_region_7',
#        'region_region_8', 'region_region_9', 'education_Bachelor's',
#        'education_Below Secondary', 'education_Master's & above', 'gender_f',
#        'gender_m', 'recruitment_channel_other', 'recruitment_channel_referred',
#        'recruitment_channel_sourcing'],
#       dtype='object')

# %% [markdown]
# **Oversampling of the Model**

# %%
from imblearn.over_sampling import SMOTE

x_sample, y_sample = SMOTE().fit_sample(x, y.values.ravel())

x_sample = pd.DataFrame(x_sample)
y_sample = pd.DataFrame(y_sample)

# checking the sizes of the sample data
print("Size of x-sample :", x_sample.shape)
print("Size of y-sample :", y_sample.shape)
# Out:
# Size of x-sample : (100280, 58)
# Size of y-sample : (100280, 1)

# %%
# splitting x and y into train and validation sets

from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x_sample, y_sample, test_size = 0.2, random_state = 0)

print("Shape of x_train: ", x_train.shape)
print("Shape of x_valid: ", x_valid.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_valid: ", y_valid.shape)
# Out:
# Shape of x_train:  (80224, 58)
# Shape of x_valid:  (20056, 58)
# Shape of y_train:  (80224, 1)
# Shape of y_valid:  (20056, 1)

# %%
# standard scaling

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test  = sc.transform(x_test)
x_valid = sc.transform(x_valid)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.

# %%
# applying pca

'''
from sklearn.decomposition import PCA

pca = PCA(n_components = None)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
x_valid = pca.transform(x_valid)

'''
# Out:
# '\nfrom sklearn.decomposition import PCA\n\npca = PCA(n_components = None)\nx_train = pca.fit_transform(x_train)\nx_test = pca.transform(x_test)\nx_valid = pca.transform(x_valid)\n\n'

# %% [markdown]
# **Modelling**

# %% [markdown]
# **Random Forest Classifer**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)

rfc_pred = rfc.predict(x_test)

print("Training Accuracy :", rfc.score(x_train, y_train))

'''
print("Validation Accuracy :", rfc.score(x_valid, y_valid))

cm = confusion_matrix(y_valid, rfc_pred)
print(cm)

cr = classification_report(y_valid, rfc_pred)
print(cr)

apc = average_precision_score(y_valid, rfc_pred)
print("Average Precision Score :", apc)
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# Training Accuracy : 0.9961358197048265
# '\nprint("Validation Accuracy :", rfc.score(x_valid, y_valid))\n\ncm = confusion_matrix(y_valid, rfc_pred)\nprint(cm)\n\ncr = classification_report(y_valid, rfc_pred)\nprint(cr)\n\napc = average_precision_score(y_valid, rfc_pred)\nprint("Average Precision Score :", apc)\n'

# %% [markdown]
# **Xg-Boost Classifier**

# %%
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

xgb = XGBClassifier()
xgb.fit(x_train, y_train)

xgb_pred = xgb.predict(x_test)

print("Training Accuracy :", xgb.score(x_train, y_train))
'''
print("Validation Accuracy :", xgb.score(x_valid, y_valid))

cm = confusion_matrix(y_valid, xgb_pred)
print(cm)

cr = classification_report(y_valid, xgb_pred)
print(cr)

apc = average_precision_score(y_valid, xgb_pred)
print("Average Precision Score :", apc)
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Accuracy : 0.9463626844834464
# '\nprint("Validation Accuracy :", xgb.score(x_valid, y_valid))\n\ncm = confusion_matrix(y_valid, xgb_pred)\nprint(cm)\n\ncr = classification_report(y_valid, xgb_pred)\nprint(cr)\n\napc = average_precision_score(y_valid, xgb_pred)\nprint("Average Precision Score :", apc)\n'

# %% [markdown]
# **Light Gradient Boosting Classifier**

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score

lgb = LGBMClassifier()
lgb.fit(x_train, y_train)

lgb_pred = lgb.predict(x_test)

print("Training Accuracy :", lgb.score(x_train, y_train))
'''
print("Validation Accuracy :", lgb.score(x_valid, y_valid))

cm = confusion_matrix(y_valid, lgb_pred)
print(cm)

cr = classification_report(y_valid, lgb_pred)
print(cr)

apc = average_precision_score(y_valid, lgb_pred)
print("Average Precision Score :", apc)
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Accuracy : 0.9664439569206222
# '\nprint("Validation Accuracy :", lgb.score(x_valid, y_valid))\n\ncm = confusion_matrix(y_valid, lgb_pred)\nprint(cm)\n\ncr = classification_report(y_valid, lgb_pred)\nprint(cr)\n\napc = average_precision_score(y_valid, lgb_pred)\nprint("Average Precision Score :", apc)\n'

# %% [markdown]
# **Extra Trees Classifier**

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(x_train, y_train)

etc_pred = etc.predict(x_test)

print("Training Accuracy :", etc.score(x_train, y_train))
'''
print("Validation Accuracy :", etc.score(x_valid, y_valid))

cm = confusion_matrix(y_valid, etc_pred)
print(cm)

cr = classification_report(y_valid, etc_pred)
print(cr)

apc = average_precision_score(y_valid, etc_pred)
print("Average Precision Score :", apc)
'''
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Training Accuracy : 0.9998753490227363
# '\nprint("Validation Accuracy :", etc.score(x_valid, y_valid))\n\ncm = confusion_matrix(y_valid, etc_pred)\nprint(cm)\n\ncr = classification_report(y_valid, etc_pred)\nprint(cr)\n\napc = average_precision_score(y_valid, etc_pred)\nprint("Average Precision Score :", apc)\n'

# %% [markdown]
# **Cat Boost Classifier**

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.6/dist-packages (0.13.1)
# Requirement already satisfied: enum34 in /usr/local/lib/python3.6/dist-packages (from catboost) (1.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from catboost) (1.11.0)
# Requirement already satisfied: pandas>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from catboost) (0.22.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from catboost) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.1->catboost) (2.5.3)

# %%
from catboost import CatBoostClassifier

cbc = CatBoostClassifier(learning_rate = 0.004, early_stopping_rounds = 100)
cbc.fit(x_train, y_train)

cbc_pred = cbc.predict(x_test)

print("Training Accuracy :", rfc.score(x_train, y_train))
'''
print("Validation Accuracy :", rfc.score(x_valid, y_valid))

cm = confusion_matrix(y_valid, cbc_pred)
print(cm)

cr = classification_report(y_valid, cbc_pred)
print(cr)

apc = average_precision_score(y_valid, cbc_pred)
print("Average Precision Score :", apc)
'''
# Out:
# 0:	learn: 0.6884366	total: 91.4ms	remaining: 1m 31s
# 1:	learn: 0.6839402	total: 184ms	remaining: 1m 31s
# 2:	learn: 0.6792554	total: 281ms	remaining: 1m 33s
# 3:	learn: 0.6746071	total: 394ms	remaining: 1m 38s
# 4:	learn: 0.6701475	total: 501ms	remaining: 1m 39s
# 5:	learn: 0.6657074	total: 616ms	remaining: 1m 42s
# 6:	learn: 0.6618648	total: 727ms	remaining: 1m 43s
# 7:	learn: 0.6578430	total: 824ms	remaining: 1m 42s
# 330:	learn: 0.2607890	total: 34.9s	remaining: 1m 10s
# 331:	learn: 0.2604526	total: 35.1s	remaining: 1m 10s
# 332:	learn: 0.2602106	total: 35.1s	remaining: 1m 10s
# 333:	learn: 0.2598678	total: 35.3s	remaining: 1m 10s
# 334:	learn: 0.2596828	total: 35.4s	remaining: 1m 10s
# 335:	learn: 0.2593471	total: 35.5s	remaining: 1m 10s
# 336:	learn: 0.2589037	total: 35.6s	remaining: 1m 9s
# 337:	learn: 0.2585302	total: 35.6s	remaining: 1m 9s
# 338:	learn: 0.2582525	total: 35.7s	remaining: 1m 9s
# 339:	learn: 0.2579789	total: 35.8s	remaining: 1m 9s
# 340:	learn: 0.2576637	total: 35.9s	remaining: 1m 9s
# 341:	learn: 0.2571024	total: 36s	remaining: 1m 9s
# 342:	learn: 0.2565348	total: 36.1s	remaining: 1m 9s
# 343:	learn: 0.2559376	total: 36.3s	remaining: 1m 9s
# 344:	learn: 0.2554617	total: 36.4s	remaining: 1m 9s
# 345:	learn: 0.2551704	total: 36.5s	remaining: 1m 8s
# 346:	learn: 0.2548077	total: 36.5s	remaining: 1m 8s
# 347:	learn: 0.2542495	total: 36.7s	remaining: 1m 8s
# 348:	learn: 0.2537963	total: 36.8s	remaining: 1m 8s
# 349:	learn: 0.2534527	total: 36.9s	remaining: 1m 8s
# 350:	learn: 0.2531462	total: 36.9s	remaining: 1m 8s
# 351:	learn: 0.2529726	total: 37s	remaining: 1m 8s
# 352:	learn: 0.2524577	total: 37.1s	remaining: 1m 8s
# 353:	learn: 0.2522891	total: 37.3s	remaining: 1m 7s
# 354:	learn: 0.2519141	total: 37.4s	remaining: 1m 7s
# 355:	learn: 0.2515728	total: 37.5s	remaining: 1m 7s
# 356:	learn: 0.2509186	total: 37.6s	remaining: 1m 7s
# 357:	learn: 0.2506649	total: 37.6s	remaining: 1m 7s
# 358:	learn: 0.2504743	total: 37.7s	remaining: 1m 7s
# 359:	learn: 0.2501814	total: 37.8s	remaining: 1m 7s
# 360:	learn: 0.2497833	total: 37.9s	remaining: 1m 7s
# 361:	learn: 0.2495512	total: 38s	remaining: 1m 7s
# 362:	learn: 0.2491906	total: 38.1s	remaining: 1m 6s
# 363:	learn: 0.2488007	total: 38.2s	remaining: 1m 6s
# 364:	learn: 0.2485687	total: 38.4s	remaining: 1m 6s
# 365:	learn: 0.2483815	total: 38.5s	remaining: 1m 6s
# 366:	learn: 0.2478955	total: 38.6s	remaining: 1m 6s
# 367:	learn: 0.2475900	total: 38.7s	remaining: 1m 6s
# 368:	learn: 0.2474155	total: 38.7s	remaining: 1m 6s
# 369:	learn: 0.2470012	total: 38.8s	remaining: 1m 6s
# 370:	learn: 0.2466037	total: 38.9s	remaining: 1m 6s
# 371:	learn: 0.2463267	total: 39s	remaining: 1m 5s
# 372:	learn: 0.2458779	total: 39.1s	remaining: 1m 5s
# 373:	learn: 0.2455302	total: 39.2s	remaining: 1m 5s
# 374:	learn: 0.2452629	total: 39.3s	remaining: 1m 5s
# 375:	learn: 0.2448909	total: 39.5s	remaining: 1m 5s
# 376:	learn: 0.2444569	total: 39.6s	remaining: 1m 5s
# 377:	learn: 0.2440146	total: 39.7s	remaining: 1m 5s
# 378:	learn: 0.2437742	total: 39.8s	remaining: 1m 5s
# 379:	learn: 0.2434505	total: 39.9s	remaining: 1m 5s
# 380:	learn: 0.2431306	total: 40s	remaining: 1m 4s
# 381:	learn: 0.2428479	total: 40.1s	remaining: 1m 4s
# 382:	learn: 0.2426624	total: 40.2s	remaining: 1m 4s
# 383:	learn: 0.2423305	total: 40.3s	remaining: 1m 4s
# 384:	learn: 0.2421725	total: 40.4s	remaining: 1m 4s
# 385:	learn: 0.2418434	total: 40.5s	remaining: 1m 4s
# 386:	learn: 0.2416082	total: 40.6s	remaining: 1m 4s
# 387:	learn: 0.2413424	total: 40.7s	remaining: 1m 4s
# 388:	learn: 0.2410548	total: 40.8s	remaining: 1m 4s
# 389:	learn: 0.2408600	total: 40.9s	remaining: 1m 3s
# 390:	learn: 0.2404718	total: 41s	remaining: 1m 3s
# 391:	learn: 0.2402138	total: 41.1s	remaining: 1m 3s
# 392:	learn: 0.2398412	total: 41.2s	remaining: 1m 3s
# 393:	learn: 0.2396790	total: 41.3s	remaining: 1m 3s
# 394:	learn: 0.2393631	total: 41.4s	remaining: 1m 3s
# 395:	learn: 0.2389810	total: 41.5s	remaining: 1m 3s
# 396:	learn: 0.2384752	total: 41.6s	remaining: 1m 3s
# 397:	learn: 0.2381471	total: 41.7s	remaining: 1m 3s
# 398:	learn: 0.2379060	total: 41.8s	remaining: 1m 2s
# 399:	learn: 0.2377645	total: 41.8s	remaining: 1m 2s
# 400:	learn: 0.2374024	total: 41.9s	remaining: 1m 2s
# 401:	learn: 0.2371930	total: 42s	remaining: 1m 2s
# 402:	learn: 0.2369499	total: 42.1s	remaining: 1m 2s
# 403:	learn: 0.2367201	total: 42.2s	remaining: 1m 2s
# 404:	learn: 0.2364371	total: 42.3s	remaining: 1m 2s
# 405:	learn: 0.2360643	total: 42.4s	remaining: 1m 2s
# 406:	learn: 0.2358325	total: 42.5s	remaining: 1m 1s
# 407:	learn: 0.2354132	total: 42.6s	remaining: 1m 1s
# 408:	learn: 0.2352420	total: 42.7s	remaining: 1m 1s
# 409:	learn: 0.2348735	total: 42.8s	remaining: 1m 1s
# 410:	learn: 0.2345321	total: 42.9s	remaining: 1m 1s
# 411:	learn: 0.2341010	total: 43s	remaining: 1m 1s
# 412:	learn: 0.2337635	total: 43.1s	remaining: 1m 1s
# 413:	learn: 0.2333480	total: 43.2s	remaining: 1m 1s
# 414:	learn: 0.2331195	total: 43.3s	remaining: 1m 1s
# 415:	learn: 0.2326945	total: 43.4s	remaining: 1m
# 416:	learn: 0.2322722	total: 43.5s	remaining: 1m
# 417:	learn: 0.2318843	total: 43.6s	remaining: 1m
# 418:	learn: 0.2317170	total: 43.8s	remaining: 1m
# 419:	learn: 0.2315198	total: 43.8s	remaining: 1m
# 420:	learn: 0.2312748	total: 43.9s	remaining: 1m
# 421:	learn: 0.2310850	total: 44s	remaining: 1m
# 422:	learn: 0.2307277	total: 44.1s	remaining: 1m
# 471:	learn: 0.2171728	total: 49s	remaining: 54.8s
# 472:	learn: 0.2170205	total: 49.1s	remaining: 54.7s
# 473:	learn: 0.2167334	total: 49.2s	remaining: 54.6s
# 474:	learn: 0.2162841	total: 49.3s	remaining: 54.5s
# 475:	learn: 0.2161362	total: 49.4s	remaining: 54.4s
# 476:	learn: 0.2160116	total: 49.5s	remaining: 54.3s
# 477:	learn: 0.2156466	total: 49.6s	remaining: 54.1s
# 478:	learn: 0.2154320	total: 49.7s	remaining: 54s
# 479:	learn: 0.2152932	total: 49.8s	remaining: 53.9s
# 480:	learn: 0.2150804	total: 49.9s	remaining: 53.8s
# 481:	learn: 0.2147913	total: 50s	remaining: 53.7s
# 482:	learn: 0.2144531	total: 50s	remaining: 53.6s
# 483:	learn: 0.2142320	total: 50.1s	remaining: 53.5s
# 484:	learn: 0.2139810	total: 50.3s	remaining: 53.4s
# 485:	learn: 0.2137251	total: 50.4s	remaining: 53.3s
# 486:	learn: 0.2134396	total: 50.5s	remaining: 53.2s
# 487:	learn: 0.2131469	total: 50.6s	remaining: 53.1s
# 488:	learn: 0.2129328	total: 50.7s	remaining: 53s
# 489:	learn: 0.2126089	total: 50.8s	remaining: 52.8s
# 490:	learn: 0.2123411	total: 50.9s	remaining: 52.7s
# 491:	learn: 0.2121445	total: 51s	remaining: 52.6s
# 492:	learn: 0.2120432	total: 51.1s	remaining: 52.5s
# 493:	learn: 0.2119396	total: 51.2s	remaining: 52.4s
# 494:	learn: 0.2116765	total: 51.3s	remaining: 52.3s
# 495:	learn: 0.2114488	total: 51.4s	remaining: 52.2s
# 496:	learn: 0.2111986	total: 51.5s	remaining: 52.1s
# 497:	learn: 0.2108800	total: 51.6s	remaining: 52s
# 498:	learn: 0.2104835	total: 51.7s	remaining: 51.9s
# 499:	learn: 0.2103485	total: 51.8s	remaining: 51.8s
# 500:	learn: 0.2101843	total: 51.9s	remaining: 51.7s
# 501:	learn: 0.2099568	total: 52s	remaining: 51.6s
# 502:	learn: 0.2096729	total: 52.1s	remaining: 51.5s
# 503:	learn: 0.2093859	total: 52.2s	remaining: 51.4s
# 504:	learn: 0.2091921	total: 52.3s	remaining: 51.2s
# 505:	learn: 0.2089314	total: 52.4s	remaining: 51.1s
# 506:	learn: 0.2086955	total: 52.5s	remaining: 51s
# 507:	learn: 0.2085034	total: 52.6s	remaining: 50.9s
# 508:	learn: 0.2081358	total: 52.7s	remaining: 50.8s
# 509:	learn: 0.2078880	total: 52.8s	remaining: 50.7s
# 510:	learn: 0.2076503	total: 52.9s	remaining: 50.6s
# 511:	learn: 0.2073517	total: 53s	remaining: 50.5s
# 512:	learn: 0.2072420	total: 53.1s	remaining: 50.4s
# 513:	learn: 0.2070075	total: 53.2s	remaining: 50.3s
# 514:	learn: 0.2068253	total: 53.3s	remaining: 50.2s
# 515:	learn: 0.2065774	total: 53.4s	remaining: 50.1s
# 516:	learn: 0.2064240	total: 53.5s	remaining: 50s
# 517:	learn: 0.2062441	total: 53.6s	remaining: 49.9s
# 566:	learn: 0.1975551	total: 58.4s	remaining: 44.6s
# 567:	learn: 0.1972782	total: 58.5s	remaining: 44.5s
# 568:	learn: 0.1970905	total: 58.6s	remaining: 44.4s
# 569:	learn: 0.1969750	total: 58.7s	remaining: 44.3s
# 570:	learn: 0.1968824	total: 58.8s	remaining: 44.2s
# 571:	learn: 0.1966263	total: 58.9s	remaining: 44.1s
# 572:	learn: 0.1965687	total: 59s	remaining: 44s
# 573:	learn: 0.1963428	total: 59.1s	remaining: 43.9s
# 574:	learn: 0.1962066	total: 59.2s	remaining: 43.8s
# 575:	learn: 0.1960301	total: 59.3s	remaining: 43.7s
# 576:	learn: 0.1959167	total: 59.4s	remaining: 43.5s
# 577:	learn: 0.1957566	total: 59.5s	remaining: 43.4s
# 578:	learn: 0.1956672	total: 59.6s	remaining: 43.3s
# 579:	learn: 0.1955037	total: 59.7s	remaining: 43.2s
# 580:	learn: 0.1954067	total: 59.8s	remaining: 43.1s
# 581:	learn: 0.1952942	total: 59.9s	remaining: 43s
# 582:	learn: 0.1951658	total: 60s	remaining: 42.9s
# 583:	learn: 0.1950305	total: 1m	remaining: 42.8s
# 584:	learn: 0.1949186	total: 1m	remaining: 42.7s
# 585:	learn: 0.1948240	total: 1m	remaining: 42.6s
# 586:	learn: 0.1947419	total: 1m	remaining: 42.5s
# 587:	learn: 0.1945876	total: 1m	remaining: 42.4s
# 588:	learn: 0.1945305	total: 1m	remaining: 42.2s
# 589:	learn: 0.1944360	total: 1m	remaining: 42.1s
# 590:	learn: 0.1943419	total: 1m	remaining: 42s
# 591:	learn: 0.1941669	total: 1m	remaining: 41.9s
# 592:	learn: 0.1940012	total: 1m	remaining: 41.8s
# 593:	learn: 0.1938372	total: 1m 1s	remaining: 41.7s
# 594:	learn: 0.1936950	total: 1m 1s	remaining: 41.6s
# 595:	learn: 0.1935303	total: 1m 1s	remaining: 41.5s
# 596:	learn: 0.1932930	total: 1m 1s	remaining: 41.4s
# 597:	learn: 0.1931652	total: 1m 1s	remaining: 41.3s
# 598:	learn: 0.1930110	total: 1m 1s	remaining: 41.2s
# 599:	learn: 0.1929171	total: 1m 1s	remaining: 41.1s
# 600:	learn: 0.1928216	total: 1m 1s	remaining: 41s
# 601:	learn: 0.1925502	total: 1m 1s	remaining: 40.9s
# 602:	learn: 0.1924599	total: 1m 1s	remaining: 40.7s
# 603:	learn: 0.1923518	total: 1m 1s	remaining: 40.6s
# 604:	learn: 0.1922708	total: 1m 2s	remaining: 40.5s
# 605:	learn: 0.1920212	total: 1m 2s	remaining: 40.5s
# 606:	learn: 0.1919812	total: 1m 2s	remaining: 40.3s
# 607:	learn: 0.1918343	total: 1m 2s	remaining: 40.2s
# 608:	learn: 0.1917371	total: 1m 2s	remaining: 40.1s
# 609:	learn: 0.1914067	total: 1m 2s	remaining: 40s
# 610:	learn: 0.1912664	total: 1m 2s	remaining: 39.9s
# 611:	learn: 0.1910310	total: 1m 2s	remaining: 39.8s
# 612:	learn: 0.1908299	total: 1m 2s	remaining: 39.7s
# 613:	learn: 0.1907058	total: 1m 3s	remaining: 39.6s
# 614:	learn: 0.1905774	total: 1m 3s	remaining: 39.5s
# 615:	learn: 0.1904499	total: 1m 3s	remaining: 39.4s
# 616:	learn: 0.1903184	total: 1m 3s	remaining: 39.3s
# 617:	learn: 0.1900875	total: 1m 3s	remaining: 39.2s
# 618:	learn: 0.1899662	total: 1m 3s	remaining: 39.1s
# 619:	learn: 0.1898760	total: 1m 3s	remaining: 39s
# 620:	learn: 0.1898311	total: 1m 3s	remaining: 38.9s
# 621:	learn: 0.1897382	total: 1m 3s	remaining: 38.8s
# 622:	learn: 0.1896683	total: 1m 3s	remaining: 38.7s
# 623:	learn: 0.1895116	total: 1m 3s	remaining: 38.6s
# 624:	learn: 0.1892857	total: 1m 4s	remaining: 38.5s
# 625:	learn: 0.1891460	total: 1m 4s	remaining: 38.4s
# 626:	learn: 0.1890141	total: 1m 4s	remaining: 38.3s
# 627:	learn: 0.1888249	total: 1m 4s	remaining: 38.2s
# 628:	learn: 0.1886445	total: 1m 4s	remaining: 38.1s
# 629:	learn: 0.1885841	total: 1m 4s	remaining: 38s
# 630:	learn: 0.1884402	total: 1m 4s	remaining: 37.9s
# 631:	learn: 0.1882625	total: 1m 4s	remaining: 37.8s
# 632:	learn: 0.1880983	total: 1m 4s	remaining: 37.6s
# 633:	learn: 0.1879597	total: 1m 5s	remaining: 37.5s
# 634:	learn: 0.1878109	total: 1m 5s	remaining: 37.5s
# 635:	learn: 0.1877079	total: 1m 5s	remaining: 37.3s
# 636:	learn: 0.1875557	total: 1m 5s	remaining: 37.2s
# 637:	learn: 0.1873822	total: 1m 5s	remaining: 37.1s
# 638:	learn: 0.1873371	total: 1m 5s	remaining: 37s
# 639:	learn: 0.1871223	total: 1m 5s	remaining: 36.9s
# 640:	learn: 0.1869080	total: 1m 5s	remaining: 36.8s
# 641:	learn: 0.1868280	total: 1m 5s	remaining: 36.7s
# 642:	learn: 0.1866744	total: 1m 5s	remaining: 36.6s
# 643:	learn: 0.1864945	total: 1m 6s	remaining: 36.5s
# 644:	learn: 0.1863943	total: 1m 6s	remaining: 36.4s
# 645:	learn: 0.1862963	total: 1m 6s	remaining: 36.3s
# 646:	learn: 0.1861778	total: 1m 6s	remaining: 36.2s
# 647:	learn: 0.1860643	total: 1m 6s	remaining: 36.1s
# 648:	learn: 0.1860231	total: 1m 6s	remaining: 36s
# 649:	learn: 0.1857507	total: 1m 6s	remaining: 35.9s
# 650:	learn: 0.1855874	total: 1m 6s	remaining: 35.8s
# 651:	learn: 0.1854649	total: 1m 6s	remaining: 35.7s
# 652:	learn: 0.1853847	total: 1m 6s	remaining: 35.6s
# 653:	learn: 0.1852386	total: 1m 7s	remaining: 35.5s
# 654:	learn: 0.1851433	total: 1m 7s	remaining: 35.4s
# 655:	learn: 0.1849189	total: 1m 7s	remaining: 35.3s
# 656:	learn: 0.1847621	total: 1m 7s	remaining: 35.2s
# 657:	learn: 0.1846585	total: 1m 7s	remaining: 35.1s
# 658:	learn: 0.1844920	total: 1m 7s	remaining: 35s
# 659:	learn: 0.1843843	total: 1m 7s	remaining: 34.9s
# 660:	learn: 0.1841887	total: 1m 7s	remaining: 34.8s
# 661:	learn: 0.1840748	total: 1m 7s	remaining: 34.7s
# 662:	learn: 0.1840059	total: 1m 7s	remaining: 34.5s
# 663:	learn: 0.1838440	total: 1m 8s	remaining: 34.5s
# 664:	learn: 0.1837966	total: 1m 8s	remaining: 34.4s
# 665:	learn: 0.1836758	total: 1m 8s	remaining: 34.3s
# 666:	learn: 0.1836080	total: 1m 8s	remaining: 34.1s
# 667:	learn: 0.1834428	total: 1m 8s	remaining: 34s
# 668:	learn: 0.1833785	total: 1m 8s	remaining: 33.9s
# 669:	learn: 0.1832587	total: 1m 8s	remaining: 33.8s
# 670:	learn: 0.1831913	total: 1m 8s	remaining: 33.7s
# 671:	learn: 0.1830900	total: 1m 8s	remaining: 33.6s
# 672:	learn: 0.1830335	total: 1m 8s	remaining: 33.5s
# 673:	learn: 0.1829326	total: 1m 9s	remaining: 33.4s
# 674:	learn: 0.1828572	total: 1m 9s	remaining: 33.3s
# 675:	learn: 0.1827074	total: 1m 9s	remaining: 33.2s
# 676:	learn: 0.1825746	total: 1m 9s	remaining: 33.1s
# 677:	learn: 0.1824227	total: 1m 9s	remaining: 33s
# 678:	learn: 0.1822903	total: 1m 9s	remaining: 32.9s
# 679:	learn: 0.1822118	total: 1m 9s	remaining: 32.8s
# 680:	learn: 0.1821784	total: 1m 9s	remaining: 32.7s
# 681:	learn: 0.1820818	total: 1m 9s	remaining: 32.6s
# 682:	learn: 0.1819481	total: 1m 9s	remaining: 32.4s
# 683:	learn: 0.1817878	total: 1m 10s	remaining: 32.3s
# 684:	learn: 0.1816787	total: 1m 10s	remaining: 32.2s
# 685:	learn: 0.1816425	total: 1m 10s	remaining: 32.1s
# 686:	learn: 0.1815383	total: 1m 10s	remaining: 32s
# 687:	learn: 0.1814724	total: 1m 10s	remaining: 31.9s
# 688:	learn: 0.1813471	total: 1m 10s	remaining: 31.8s
# 689:	learn: 0.1812259	total: 1m 10s	remaining: 31.7s
# 690:	learn: 0.1811476	total: 1m 10s	remaining: 31.6s
# 691:	learn: 0.1810338	total: 1m 10s	remaining: 31.5s
# 692:	learn: 0.1808985	total: 1m 10s	remaining: 31.4s
# 693:	learn: 0.1808024	total: 1m 11s	remaining: 31.3s
# 694:	learn: 0.1807237	total: 1m 11s	remaining: 31.2s
# 695:	learn: 0.1805859	total: 1m 11s	remaining: 31.1s
# 696:	learn: 0.1804268	total: 1m 11s	remaining: 31s
# 697:	learn: 0.1803222	total: 1m 11s	remaining: 30.9s
# 698:	learn: 0.1802926	total: 1m 11s	remaining: 30.8s
# 699:	learn: 0.1801667	total: 1m 11s	remaining: 30.7s
# 700:	learn: 0.1800239	total: 1m 11s	remaining: 30.6s
# 701:	learn: 0.1799952	total: 1m 11s	remaining: 30.5s
# 702:	learn: 0.1798784	total: 1m 11s	remaining: 30.4s
# 703:	learn: 0.1797296	total: 1m 12s	remaining: 30.3s
# 704:	learn: 0.1796967	total: 1m 12s	remaining: 30.2s
# 705:	learn: 0.1795773	total: 1m 12s	remaining: 30.1s
# 706:	learn: 0.1795293	total: 1m 12s	remaining: 30s
# 707:	learn: 0.1794510	total: 1m 12s	remaining: 29.9s
# 708:	learn: 0.1793819	total: 1m 12s	remaining: 29.8s
# 709:	learn: 0.1793428	total: 1m 12s	remaining: 29.6s
# 710:	learn: 0.1791932	total: 1m 12s	remaining: 29.5s
# 711:	learn: 0.1790495	total: 1m 12s	remaining: 29.4s
# 712:	learn: 0.1788487	total: 1m 12s	remaining: 29.3s
# 713:	learn: 0.1786713	total: 1m 12s	remaining: 29.2s
# 714:	learn: 0.1786174	total: 1m 13s	remaining: 29.1s
# 715:	learn: 0.1785263	total: 1m 13s	remaining: 29s
# 716:	learn: 0.1784598	total: 1m 13s	remaining: 28.9s
# 717:	learn: 0.1782834	total: 1m 13s	remaining: 28.8s
# 718:	learn: 0.1780907	total: 1m 13s	remaining: 28.7s
# 719:	learn: 0.1779870	total: 1m 13s	remaining: 28.6s
# 720:	learn: 0.1779537	total: 1m 13s	remaining: 28.5s
# 721:	learn: 0.1778404	total: 1m 13s	remaining: 28.4s
# 722:	learn: 0.1777913	total: 1m 13s	remaining: 28.3s
# 723:	learn: 0.1776513	total: 1m 13s	remaining: 28.2s
# 724:	learn: 0.1775864	total: 1m 14s	remaining: 28.1s
# 725:	learn: 0.1775397	total: 1m 14s	remaining: 28s
# 726:	learn: 0.1774806	total: 1m 14s	remaining: 27.9s
# 727:	learn: 0.1772206	total: 1m 14s	remaining: 27.8s
# 728:	learn: 0.1771260	total: 1m 14s	remaining: 27.7s
# 729:	learn: 0.1770084	total: 1m 14s	remaining: 27.6s
# 730:	learn: 0.1769721	total: 1m 14s	remaining: 27.5s
# 731:	learn: 0.1767120	total: 1m 14s	remaining: 27.4s
# 732:	learn: 0.1766399	total: 1m 14s	remaining: 27.3s
# 733:	learn: 0.1765957	total: 1m 14s	remaining: 27.2s
# 734:	learn: 0.1764969	total: 1m 15s	remaining: 27.1s
# 735:	learn: 0.1764134	total: 1m 15s	remaining: 26.9s
# 736:	learn: 0.1763717	total: 1m 15s	remaining: 26.9s
# 737:	learn: 0.1761956	total: 1m 15s	remaining: 26.7s
# 738:	learn: 0.1761351	total: 1m 15s	remaining: 26.6s
# 739:	learn: 0.1760338	total: 1m 15s	remaining: 26.5s
# 740:	learn: 0.1758644	total: 1m 15s	remaining: 26.4s
# 741:	learn: 0.1757980	total: 1m 15s	remaining: 26.3s
# 742:	learn: 0.1757179	total: 1m 15s	remaining: 26.2s
# 743:	learn: 0.1755543	total: 1m 15s	remaining: 26.1s
# 744:	learn: 0.1753499	total: 1m 16s	remaining: 26s
# 745:	learn: 0.1752147	total: 1m 16s	remaining: 25.9s
# 746:	learn: 0.1751065	total: 1m 16s	remaining: 25.8s
# 747:	learn: 0.1749644	total: 1m 16s	remaining: 25.7s
# 748:	learn: 0.1748772	total: 1m 16s	remaining: 25.6s
# 749:	learn: 0.1748271	total: 1m 16s	remaining: 25.5s
# 750:	learn: 0.1747223	total: 1m 16s	remaining: 25.4s
# 751:	learn: 0.1746214	total: 1m 16s	remaining: 25.3s
# 752:	learn: 0.1744543	total: 1m 16s	remaining: 25.2s
# 753:	learn: 0.1742691	total: 1m 16s	remaining: 25.1s
# 754:	learn: 0.1741347	total: 1m 17s	remaining: 25s
# 755:	learn: 0.1740872	total: 1m 17s	remaining: 24.9s
# 756:	learn: 0.1739256	total: 1m 17s	remaining: 24.8s
# 757:	learn: 0.1738252	total: 1m 17s	remaining: 24.7s
# 758:	learn: 0.1737066	total: 1m 17s	remaining: 24.6s
# 759:	learn: 0.1735317	total: 1m 17s	remaining: 24.5s
# 760:	learn: 0.1734477	total: 1m 17s	remaining: 24.4s
# 761:	learn: 0.1733975	total: 1m 17s	remaining: 24.3s
# 762:	learn: 0.1733146	total: 1m 17s	remaining: 24.2s
# 763:	learn: 0.1731693	total: 1m 17s	remaining: 24.1s
# 764:	learn: 0.1731014	total: 1m 18s	remaining: 24s
# 765:	learn: 0.1729851	total: 1m 18s	remaining: 23.9s
# 766:	learn: 0.1729024	total: 1m 18s	remaining: 23.8s
# 767:	learn: 0.1728055	total: 1m 18s	remaining: 23.7s
# 768:	learn: 0.1726697	total: 1m 18s	remaining: 23.6s
# 769:	learn: 0.1726083	total: 1m 18s	remaining: 23.5s
# 770:	learn: 0.1724739	total: 1m 18s	remaining: 23.4s
# 771:	learn: 0.1724127	total: 1m 18s	remaining: 23.3s
# 772:	learn: 0.1722962	total: 1m 18s	remaining: 23.2s
# 773:	learn: 0.1722479	total: 1m 19s	remaining: 23.1s
# 774:	learn: 0.1720987	total: 1m 19s	remaining: 23s
# 775:	learn: 0.1720466	total: 1m 19s	remaining: 22.9s
# 776:	learn: 0.1719999	total: 1m 19s	remaining: 22.8s
# 777:	learn: 0.1719359	total: 1m 19s	remaining: 22.7s
# 778:	learn: 0.1718200	total: 1m 19s	remaining: 22.6s
# 779:	learn: 0.1717666	total: 1m 19s	remaining: 22.4s
# 780:	learn: 0.1717055	total: 1m 19s	remaining: 22.3s
# 781:	learn: 0.1715747	total: 1m 19s	remaining: 22.2s
# 782:	learn: 0.1714922	total: 1m 19s	remaining: 22.1s
# 783:	learn: 0.1713074	total: 1m 20s	remaining: 22s
# 784:	learn: 0.1712431	total: 1m 20s	remaining: 21.9s
# 785:	learn: 0.1711139	total: 1m 20s	remaining: 21.8s
# 786:	learn: 0.1710224	total: 1m 20s	remaining: 21.7s
# 787:	learn: 0.1709677	total: 1m 20s	remaining: 21.6s
# 788:	learn: 0.1708854	total: 1m 20s	remaining: 21.5s
# 789:	learn: 0.1708292	total: 1m 20s	remaining: 21.4s
# 790:	learn: 0.1707655	total: 1m 20s	remaining: 21.3s
# 791:	learn: 0.1706823	total: 1m 20s	remaining: 21.2s
# 792:	learn: 0.1706313	total: 1m 20s	remaining: 21.1s
# 793:	learn: 0.1705280	total: 1m 21s	remaining: 21s
# 794:	learn: 0.1704638	total: 1m 21s	remaining: 20.9s
# 795:	learn: 0.1703183	total: 1m 21s	remaining: 20.8s
# 796:	learn: 0.1702762	total: 1m 21s	remaining: 20.7s
# 797:	learn: 0.1702372	total: 1m 21s	remaining: 20.6s
# 798:	learn: 0.1701981	total: 1m 21s	remaining: 20.5s
# 799:	learn: 0.1700838	total: 1m 21s	remaining: 20.4s
# 800:	learn: 0.1699569	total: 1m 21s	remaining: 20.3s
# 801:	learn: 0.1698923	total: 1m 21s	remaining: 20.2s
# 802:	learn: 0.1698676	total: 1m 21s	remaining: 20.1s
# 803:	learn: 0.1697349	total: 1m 21s	remaining: 20s
# 804:	learn: 0.1697114	total: 1m 22s	remaining: 19.9s
# 805:	learn: 0.1696454	total: 1m 22s	remaining: 19.8s
# 806:	learn: 0.1696218	total: 1m 22s	remaining: 19.7s
# 807:	learn: 0.1695767	total: 1m 22s	remaining: 19.6s
# 808:	learn: 0.1694782	total: 1m 22s	remaining: 19.5s
# 809:	learn: 0.1693681	total: 1m 22s	remaining: 19.4s
# 810:	learn: 0.1693262	total: 1m 22s	remaining: 19.3s
# 811:	learn: 0.1692081	total: 1m 22s	remaining: 19.2s
# 812:	learn: 0.1691424	total: 1m 22s	remaining: 19.1s
# 813:	learn: 0.1691097	total: 1m 22s	remaining: 19s
# 814:	learn: 0.1690661	total: 1m 23s	remaining: 18.9s
# 815:	learn: 0.1690306	total: 1m 23s	remaining: 18.8s
# 816:	learn: 0.1688581	total: 1m 23s	remaining: 18.7s
# 817:	learn: 0.1687651	total: 1m 23s	remaining: 18.6s
# 818:	learn: 0.1686776	total: 1m 23s	remaining: 18.5s
# 819:	learn: 0.1686288	total: 1m 23s	remaining: 18.4s
# 820:	learn: 0.1685826	total: 1m 23s	remaining: 18.2s
# 821:	learn: 0.1684724	total: 1m 23s	remaining: 18.1s
# 822:	learn: 0.1684248	total: 1m 23s	remaining: 18s
# 823:	learn: 0.1683491	total: 1m 23s	remaining: 17.9s
# 824:	learn: 0.1681564	total: 1m 24s	remaining: 17.8s
# 825:	learn: 0.1680650	total: 1m 24s	remaining: 17.7s
# 826:	learn: 0.1679242	total: 1m 24s	remaining: 17.6s
# 827:	learn: 0.1678214	total: 1m 24s	remaining: 17.5s
# 828:	learn: 0.1677962	total: 1m 24s	remaining: 17.4s
# 829:	learn: 0.1676211	total: 1m 24s	remaining: 17.3s
# 830:	learn: 0.1675737	total: 1m 24s	remaining: 17.2s
# 831:	learn: 0.1675158	total: 1m 24s	remaining: 17.1s
# 832:	learn: 0.1674845	total: 1m 24s	remaining: 17s
# 833:	learn: 0.1674229	total: 1m 25s	remaining: 16.9s
# 834:	learn: 0.1673073	total: 1m 25s	remaining: 16.8s
# 835:	learn: 0.1672364	total: 1m 25s	remaining: 16.7s
# 836:	learn: 0.1671024	total: 1m 25s	remaining: 16.6s
# 837:	learn: 0.1669964	total: 1m 25s	remaining: 16.5s
# 838:	learn: 0.1669565	total: 1m 25s	remaining: 16.4s
# 839:	learn: 0.1669157	total: 1m 25s	remaining: 16.3s
# 840:	learn: 0.1668708	total: 1m 25s	remaining: 16.2s
# 841:	learn: 0.1668401	total: 1m 25s	remaining: 16.1s
# 842:	learn: 0.1667487	total: 1m 25s	remaining: 16s
# 843:	learn: 0.1666009	total: 1m 25s	remaining: 15.9s
# 844:	learn: 0.1664987	total: 1m 26s	remaining: 15.8s
# 845:	learn: 0.1664140	total: 1m 26s	remaining: 15.7s
# 846:	learn: 0.1663243	total: 1m 26s	remaining: 15.6s
# 847:	learn: 0.1662404	total: 1m 26s	remaining: 15.5s
# 848:	learn: 0.1661724	total: 1m 26s	remaining: 15.4s
# 849:	learn: 0.1661409	total: 1m 26s	remaining: 15.3s
# 850:	learn: 0.1660295	total: 1m 26s	remaining: 15.2s
# 851:	learn: 0.1660065	total: 1m 26s	remaining: 15.1s
# 852:	learn: 0.1659748	total: 1m 26s	remaining: 15s
# 853:	learn: 0.1658955	total: 1m 26s	remaining: 14.9s
# 854:	learn: 0.1657625	total: 1m 27s	remaining: 14.8s
# 855:	learn: 0.1656827	total: 1m 27s	remaining: 14.7s
# 856:	learn: 0.1655802	total: 1m 27s	remaining: 14.6s
# 857:	learn: 0.1655563	total: 1m 27s	remaining: 14.5s
# 858:	learn: 0.1655347	total: 1m 27s	remaining: 14.4s
# 859:	learn: 0.1654221	total: 1m 27s	remaining: 14.3s
# 860:	learn: 0.1653419	total: 1m 27s	remaining: 14.2s
# 861:	learn: 0.1653059	total: 1m 27s	remaining: 14.1s
# 862:	learn: 0.1652285	total: 1m 27s	remaining: 14s
# 863:	learn: 0.1651061	total: 1m 27s	remaining: 13.8s
# 864:	learn: 0.1650430	total: 1m 28s	remaining: 13.7s
# 865:	learn: 0.1649778	total: 1m 28s	remaining: 13.6s
# 866:	learn: 0.1648620	total: 1m 28s	remaining: 13.5s
# 867:	learn: 0.1648054	total: 1m 28s	remaining: 13.4s
# 868:	learn: 0.1647195	total: 1m 28s	remaining: 13.3s
# 869:	learn: 0.1646845	total: 1m 28s	remaining: 13.2s
# 870:	learn: 0.1646503	total: 1m 28s	remaining: 13.1s
# 871:	learn: 0.1645662	total: 1m 28s	remaining: 13s
# 872:	learn: 0.1644816	total: 1m 28s	remaining: 12.9s
# 873:	learn: 0.1644128	total: 1m 28s	remaining: 12.8s
# 874:	learn: 0.1643798	total: 1m 29s	remaining: 12.7s
# 875:	learn: 0.1643638	total: 1m 29s	remaining: 12.6s
# 876:	learn: 0.1642608	total: 1m 29s	remaining: 12.5s
# 877:	learn: 0.1642432	total: 1m 29s	remaining: 12.4s
# 878:	learn: 0.1641425	total: 1m 29s	remaining: 12.3s
# 879:	learn: 0.1641126	total: 1m 29s	remaining: 12.2s
# 880:	learn: 0.1640407	total: 1m 29s	remaining: 12.1s
# 881:	learn: 0.1639671	total: 1m 29s	remaining: 12s
# 882:	learn: 0.1639267	total: 1m 29s	remaining: 11.9s
# 883:	learn: 0.1638884	total: 1m 29s	remaining: 11.8s
# 884:	learn: 0.1638323	total: 1m 30s	remaining: 11.7s
# 885:	learn: 0.1637725	total: 1m 30s	remaining: 11.6s
# 886:	learn: 0.1636417	total: 1m 30s	remaining: 11.5s
# 887:	learn: 0.1636169	total: 1m 30s	remaining: 11.4s
# 888:	learn: 0.1634709	total: 1m 30s	remaining: 11.3s
# 889:	learn: 0.1634031	total: 1m 30s	remaining: 11.2s
# 982:	learn: 0.1579904	total: 1m 39s	remaining: 1.73s
# 983:	learn: 0.1579409	total: 1m 39s	remaining: 1.63s
# 984:	learn: 0.1579004	total: 1m 40s	remaining: 1.52s
# 985:	learn: 0.1578695	total: 1m 40s	remaining: 1.42s
# 986:	learn: 0.1578060	total: 1m 40s	remaining: 1.32s
# 987:	learn: 0.1577255	total: 1m 40s	remaining: 1.22s
# 988:	learn: 0.1576061	total: 1m 40s	remaining: 1.12s
# 989:	learn: 0.1575597	total: 1m 40s	remaining: 1.01s
# 990:	learn: 0.1574919	total: 1m 40s	remaining: 914ms
# 991:	learn: 0.1574459	total: 1m 40s	remaining: 812ms
# 992:	learn: 0.1574125	total: 1m 40s	remaining: 711ms
# 993:	learn: 0.1573508	total: 1m 40s	remaining: 609ms
# 994:	learn: 0.1572759	total: 1m 41s	remaining: 508ms
# 995:	learn: 0.1571777	total: 1m 41s	remaining: 406ms
# 996:	learn: 0.1571639	total: 1m 41s	remaining: 305ms
# 997:	learn: 0.1571172	total: 1m 41s	remaining: 203ms
# 998:	learn: 0.1570747	total: 1m 41s	remaining: 102ms
# 999:	learn: 0.1570496	total: 1m 41s	remaining: 0us
# Training Accuracy : 0.9961358197048265
# '\nprint("Validation Accuracy :", rfc.score(x_valid, y_valid))\n\ncm = confusion_matrix(y_valid, cbc_pred)\nprint(cm)\n\ncr = classification_report(y_valid, cbc_pred)\nprint(cr)\n\napc = average_precision_score(y_valid, cbc_pred)\nprint("Average Precision Score :", apc)\n'

# %% [markdown]
# **Stacking of models**

# %%
'''

# defining the stacked predictions

stacked_predictions = np.column_stack((rfc_pred, xgb_pred, cbc_pred))

# specifyinng the meta model
meta_model = RandomForestClassifier()
meta_model.fit(stacked_predictions, )

# final predictions
stacked_predictions = meta_model.predict(stacked_predictions)

cm = confusion_matrix(y_valid, stacked_predictions)
print(cm)

cr = classification_report(y_valid, stacked_predictions)
print(cr)

apc = average_precision_score(y_valid, stacked_predictions)
print("Average Precision Score :", apc)
'''

# %% [markdown]
# **Boosting the Model**

# %%
boosted_predictions = rfc_pred*0.2 + xgb_pred*0.2 + lgb_pred*0.4 + etc_pred*0.3

'''
apc = average_precision_score(y_valid, boosted_predictions)
print("Average Precision Score :", apc)
'''
# Out:
# '\napc = average_precision_score(y_valid, boosted_predictions)\nprint("Average Precision Score :", apc)\n'

# %%
# looking at the pattern of the submission file

submission = pd.read_csv('drive/My Drive/Projects/HR Analytics/sample_submission.csv')

submission.head()
# Out:
#    employee_id  is_promoted
# 0         8724            0
# 1        74430            0
# 2        72255            0
# 3        38562            0
# 4        64486            0

# %%
# creating a dataframe with the employee id and their predicted promoted values{0, 1}

submission = pd.DataFrame({'employee_id': emp_id,'is_promoted': boosted_predictions})

submission.head()
# Out:
#    employee_id  is_promoted
# 0         8724          0.0
# 1        74430          0.0
# 2        72255          0.0
# 3        38562          0.0
# 4        64486          0.0

# %%
# saving the submission file

filename = 'submission.csv'
submission.to_csv(filename, index = False)

print("Saved File : ", filename)
# Out:
# Saved File :  submission.csv
